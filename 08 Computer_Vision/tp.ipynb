# %%
import pandas as pd
from lr_def import *

# %%
file='../team_project/train.csv'
df=pd.read_csv(file)
df=pd.DataFrame(df)
df
# Out:
#                       img_path                 upscale_img_path  \
# 0      ./train/TRAIN_00000.jpg  ./upscale_train/TRAIN_00000.png
# 1      ./train/TRAIN_00001.jpg  ./upscale_train/TRAIN_00001.png
# 2      ./train/TRAIN_00002.jpg  ./upscale_train/TRAIN_00002.png
# 3      ./train/TRAIN_00003.jpg  ./upscale_train/TRAIN_00003.png
# 4      ./train/TRAIN_00004.jpg  ./upscale_train/TRAIN_00004.png
# ...                        ...                              ...
# 15829  ./train/TRAIN_15829.jpg  ./upscale_train/TRAIN_15829.png
# 15830  ./train/TRAIN_15830.jpg  ./upscale_train/TRAIN_15830.png
# 15831  ./train/TRAIN_15831.jpg  ./upscale_train/TRAIN_15831.png
# 15832  ./train/TRAIN_15832.jpg  ./upscale_train/TRAIN_15832.png
# 15833  ./train/TRAIN_15833.jpg  ./upscale_train/TRAIN_15833.png
#
#                    label
# 0         Ruddy Shelduck
# 1           Gray Wagtail
# 2         Indian Peacock
# 3      Common Kingfisher
# 4      Common Kingfisher
# ...                  ...
# ...

# %%
ddf=df.groupby('label')

# %%
ddf=pd.DataFrame(ddf)

# %%
ddf
# Out:
#                             0  \
# 0       Asian Green Bee-Eater
# 1         Brown-Headed Barbet
# 2                Cattle Egret
# 3           Common Kingfisher
# 4                 Common Myna
# 5            Common Rosefinch
# 6           Common Tailorbird
# 7          Coppersmith Barbet
# 8              Forest Wagtail
# 9                Gray Wagtail
# 10                     Hoopoe
# 11                 House Crow
# 12       Indian Grey Hornbill
# 13             Indian Peacock
# 14               Indian Pitta
# 15              Indian Roller
# 16             Jungle Babbler
# 17           Northern Lapwing
# 18        Red-Wattled Lapwing
# 19             Ruddy Shelduck
# 20             Rufous Treepie
# 21                Sarus Crane
# 22              White Wagtail
# 23  White-Breasted Kingfisher
# 24    White-Breasted Waterhen
#
#                                                     1
# 0                         img_path                ...
# ...

# %%
train_all_models_from_images_color('../team_project/labeled_train.csv','../team_project/test.csv',
                             '과')
# Out:
# [학습셋] 15834 개, [테스트셋] 6786 개
#
# === KFold 교차검증 (n_splits=5) ===
#
# [모델: Logistic]
# - KFold Mean Acc=0.2345, F1=0.2035
#
# [모델: SVC]
